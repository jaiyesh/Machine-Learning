# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def datamaker(N=100, err=1.0):

  x = np.linspace(-1,1,N)

  y = 2*x - 3

  y = y + err*np.random.randn(N)

  return x , y

# %%
X_train , y_train = datamaker(500,0.2)

#Important. 
X_train = X_train[:,np.newaxis]

plt.scatter(X_train, y_train)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

model.fit(X_train, y_train, )
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.style.use('default')

plt.scatter(X_train,y_train)
plt.plot(X_train , model.predict(X_train) , c='r', lw=2)

plt.title('Training Performance')
# Out:
# Text(0.5, 1.0, 'Training Performance')

# %%
X_test , y_test = datamaker(50,0.2)

X_test = X_test[:,np.newaxis]

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test , model.predict(X_test) , c='red')

plt.title('Testing performance')
# Out:
# Text(0.5, 1.0, 'Testing performance')

# %%
y_pred = model.predict(X_test)

# %%
X_test = X_test.reshape(50,)

# %%
df = pd.DataFrame({'X':X_test,'y_actual':y_test,'y_predicted':y_pred})

# %%
df
# Out:
#            X  y_actual  y_predicted
# 0  -1.000000 -5.336428    -4.997379
# 1  -0.959184 -4.843855    -4.916560
# 2  -0.918367 -4.778067    -4.835741
# 3  -0.877551 -4.929418    -4.754922
# 4  -0.836735 -4.296910    -4.674103
# 5  -0.795918 -4.861896    -4.593284
# 6  -0.755102 -4.603720    -4.512465
# 7  -0.714286 -4.391749    -4.431646
# 8  -0.673469 -4.490947    -4.350827
# 9  -0.632653 -4.236117    -4.270008
# 10 -0.591837 -4.266488    -4.189189
# 11 -0.551020 -3.954948    -4.108370
# 12 -0.510204 -3.975007    -4.027551
# 13 -0.469388 -4.116399    -3.946732
# 14 -0.428571 -3.980427    -3.865913
# 15 -0.387755 -3.743531    -3.785094
# 16 -0.346939 -3.295323    -3.704275
# 17 -0.306122 -3.420977    -3.623456
# 18 -0.265306 -3.418758    -3.542637
# 19 -0.224490 -3.142810    -3.461818
# 20 -0.183673 -3.258843    -3.380999
# 21 -0.142857 -3.056035    -3.300180
# 22 -0.102041 -3.425144    -3.219361
# 23 -0.061224 -3.200457    -3.138542
# 24 -0.020408 -3.195494    -3.057723
# 25  0.020408 -2.926046    -2.976904
# 26  0.061224 -2.862212    -2.896085
# 27  0.102041 -2.815648    -2.815266
# 28  0.142857 -2.609351    -2.734447
# 29  0.183673 -2.673621    -2.653628
# 30  0.224490 -2.901286    -2.572809
# 31  0.265306 -2.543929    -2.491990
# 32  0.306122 -2.432751    -2.411171
# 33  0.346939 -2.660274    -2.330352
# 34  0.387755 -2.213346    -2.249533
# 35  0.428571 -2.518688    -2.168715
# 36  0.469388 -2.055815    -2.087896
# 37  0.510204 -1.702690    -2.007077
# 38  0.551020 -1.740455    -1.926258
# 39  0.591837 -2.234129    -1.845439
# 40  0.632653 -1.754203    -1.764620
# 41  0.673469 -1.677579    -1.683801
# 42  0.714286 -1.625816    -1.602982
# 43  0.755102 -1.508460    -1.522163
# 44  0.795918 -1.193151    -1.441344
# 45  0.836735 -1.145202    -1.360525
# 46  0.877551 -1.120763    -1.279706
# 47  0.918367 -1.267911    -1.198887
# 48  0.959184 -0.933590    -1.118068
# 49  1.000000 -1.269786    -1.037249

# %%
df['loss'] = df['y_actual'] - df['y_predicted']

# %%
df
# Out:
#            X  y_actual  y_predicted      loss
# 0  -1.000000 -5.336428    -4.997379 -0.339049
# 1  -0.959184 -4.843855    -4.916560  0.072705
# 2  -0.918367 -4.778067    -4.835741  0.057673
# 3  -0.877551 -4.929418    -4.754922 -0.174496
# 4  -0.836735 -4.296910    -4.674103  0.377193
# 5  -0.795918 -4.861896    -4.593284 -0.268612
# 6  -0.755102 -4.603720    -4.512465 -0.091255
# 7  -0.714286 -4.391749    -4.431646  0.039897
# 8  -0.673469 -4.490947    -4.350827 -0.140120
# 9  -0.632653 -4.236117    -4.270008  0.033891
# 10 -0.591837 -4.266488    -4.189189 -0.077299
# 11 -0.551020 -3.954948    -4.108370  0.153422
# 12 -0.510204 -3.975007    -4.027551  0.052545
# 13 -0.469388 -4.116399    -3.946732 -0.169667
# 14 -0.428571 -3.980427    -3.865913 -0.114514
# 15 -0.387755 -3.743531    -3.785094  0.041563
# 16 -0.346939 -3.295323    -3.704275  0.408952
# 17 -0.306122 -3.420977    -3.623456  0.202480
# 18 -0.265306 -3.418758    -3.542637  0.123879
# 19 -0.224490 -3.142810    -3.461818  0.319008
# 20 -0.183673 -3.258843    -3.380999  0.122156
# 21 -0.142857 -3.056035    -3.300180  0.244146
# 22 -0.102041 -3.425144    -3.219361 -0.205783
# 23 -0.061224 -3.200457    -3.138542 -0.061915
# 24 -0.020408 -3.195494    -3.057723 -0.137770
# 25  0.020408 -2.926046    -2.976904  0.050859
# 26  0.061224 -2.862212    -2.896085  0.033873
# 27  0.102041 -2.815648    -2.815266 -0.000382
# 28  0.142857 -2.609351    -2.734447  0.125096
# 29  0.183673 -2.673621    -2.653628 -0.019992
# 30  0.224490 -2.901286    -2.572809 -0.328477
# 31  0.265306 -2.543929    -2.491990 -0.051938
# 32  0.306122 -2.432751    -2.411171 -0.021580
# 33  0.346939 -2.660274    -2.330352 -0.329922
# 34  0.387755 -2.213346    -2.249533  0.036187
# 35  0.428571 -2.518688    -2.168715 -0.349974
# 36  0.469388 -2.055815    -2.087896  0.032080
# 37  0.510204 -1.702690    -2.007077  0.304386
# 38  0.551020 -1.740455    -1.926258  0.185802
# 39  0.591837 -2.234129    -1.845439 -0.388690
# 40  0.632653 -1.754203    -1.764620  0.010416
# 41  0.673469 -1.677579    -1.683801  0.006222
# 42  0.714286 -1.625816    -1.602982 -0.022834
# 43  0.755102 -1.508460    -1.522163  0.013703
# 44  0.795918 -1.193151    -1.441344  0.248193
# 45  0.836735 -1.145202    -1.360525  0.215323
# 46  0.877551 -1.120763    -1.279706  0.158943
# 47  0.918367 -1.267911    -1.198887 -0.069025
# 48  0.959184 -0.933590    -1.118068  0.184478
# 49  1.000000 -1.269786    -1.037249 -0.232538

# %%
import seaborn as sns

# %%
sns.displot(x = df['loss'],kde=True)

# %%
from sklearn.metrics import mean_squared_error

rms = mean_squared_error(y_test, y_pred)

rms = np.sqrt(rms)

# %%
rms
# Out:
# 0.1902528052392727

# %%
3*rms
# Out:
# 0.5707584157178182

# %%
#Standard deviation of Loss column
a = np.std(df['loss'])

# %%
a
# Out:
# 0.1901821445417778

# %%
"Thank You".center(40,'#')
# Out:
# '###############Thank You################'

# %% [markdown]
# # ########
